# %%
apps = [
    'bc-3.txt.xz',
    'bfs-3.txt.xz',
    'cc-13.txt.xz',
    'pr-3.txt.xz',
    'sssp-3.txt.xz'
]

models = ['l']

for app in apps:
    for model in models:
        # !python src/train_stu.py {app} 0.5 {model} {model} 3
# Out:
# ...
# Layer (type:depth-idx)                   Param #
# ...
# LSTMModel                                --
# ├─Flatten: 1-1                           --
# ├─LSTM: 1-2                              7,552
# ├─Linear: 1-3                            4,352
# ...
# Total params: 11,904
# Trainable params: 11,904
# Non-trainable params: 0
# ...
# Layer (type:depth-idx)                   Param #
# ...
# LSTMModel                                --
# ├─Flatten: 1-1                           --
# ├─LSTM: 1-2                              7,552
# ├─Linear: 1-3                            4,352
# ...
# Total params: 11,904
# Trainable params: 11,904
# Non-trainable params: 0
# ...
# -------------Start Epoch 1-------------
# 100%|██████████████████████████████████████| 1232/1232 [00:09<00:00, 136.40it/s]
# Epoch  1 Val: opt_threshold=0.21408908069133759, precision=0.1251819819593027, precision_5=0.0, recall=0.9998359409617026, recall_5=0.0, accuracy=0.22250569021826805, accuracy_5=0.0
# ...
