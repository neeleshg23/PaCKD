# %%
apps = [
    'bc-3.txt.xz',
    'bfs-3.txt.xz',
    'cc-13.txt.xz',
    'pr-3.txt.xz',
    'sssp-3.txt.xz'
]

models = ['r']

for app in apps:
    for model in models:
        # !python src/train_stu.py {app} 0.5 {model} {model} 4
# Out:
# ...
# Layer (type:depth-idx)                   Param #
# ...
# ResNet_tiny                              --
# ├─Sequential: 1-1                        --
# │    └─Conv2d: 2-1                       36
# │    └─BatchNorm2d: 2-2                  8
# │    └─ReLU: 2-3                         --
# ├─Sequential: 1-2                        --
# │    └─BasicBlock: 2-4                   --
# │    │    └─Sequential: 3-1              304
# │    │    └─Sequential: 3-2              --
# ├─Sequential: 1-3                        --
# │    └─BasicBlock: 2-5                   --
# │    │    └─Sequential: 3-3              896
# │    │    └─Sequential: 3-4              48
# ├─Sequential: 1-4                        --
# │    └─BasicBlock: 2-6                   --
# │    │    └─Sequential: 3-5              3,520
# │    │    └─Sequential: 3-6              160
# ├─AdaptiveAvgPool2d: 1-5                 --
# ├─Linear: 1-6                            4,352
# ...
# Total params: 9,324
# Trainable params: 9,324
# ...
