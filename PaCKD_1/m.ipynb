# %%
apps = [
    'bc-3.txt.xz',
    'bfs-3.txt.xz',
    'cc-13.txt.xz',
    'pr-3.txt.xz',
    'sssp-3.txt.xz'
]

models = ['m']

for app in apps:
    for model in models:
        # !python src/train_stu.py {app} 0.5 {model} {model} 2
# Out:
# ...
# Layer (type:depth-idx)                   Param #
# ...
# Sequential                               --
# ├─Rearrange: 1-1                         --
# ├─Linear: 1-2                            3,232
# ├─Sequential: 1-3                        --
# │    └─PreNormResidual: 2-1              --
# │    │    └─Sequential: 3-1              13
# │    │    └─LayerNorm: 3-2               64
# │    └─PreNormResidual: 2-2              --
# │    │    └─Sequential: 3-3              1,072
# │    │    └─LayerNorm: 3-4               64
# ├─Sequential: 1-4                        --
# │    └─PreNormResidual: 2-3              --
# │    │    └─Sequential: 3-5              13
# │    │    └─LayerNorm: 3-6               64
# │    └─PreNormResidual: 2-4              --
# │    │    └─Sequential: 3-7              1,072
# │    │    └─LayerNorm: 3-8               64
# ├─LayerNorm: 1-5                         64
# ├─Reduce: 1-6                            --
# ├─Linear: 1-7                            8,448
# ...
